# %%
import pandas as pd 
import numpy as np
import time
from datetime import datetime
import pymysql
from sqlalchemy import create_engine
def parse_ymd(s):
    year_s, mon_s, day_s = s.split('-')
    return datetime(int(year_s), int(mon_s), int(day_s))
engine1 = create_engine('mysql+pymysql://root:ASDFasdf123.@192.168.1.209:3306/shipping_list')

# %%
import glob
list_dfs = []
for f in glob.glob(r'C:/Users/LC-/Desktop/新建文件夹/*.xlsx'):
    print('合并列表',f)
    f1 = pd.read_excel(f)
    list_dfs.append(f1)
list_dfs
df3 = pd.concat(list_dfs,axis =0,ignore_index = True)
df3
# Out:
# 合并列表 C:/Users/LC-/Desktop/新建文件夹\上海23年5月发货列表.xlsx
# 合并列表 C:/Users/LC-/Desktop/新建文件夹\北京23年5月发货列表.xlsx
# 合并列表 C:/Users/LC-/Desktop/新建文件夹\广州23年5月发货列表.xlsx
#                 发货单号                     订单号        发货日期 退货标识  销售类型  \
# 0       DP2305020337    SHA230502002711814eq  2023-05-02  发货单  网站预订
# 1       DP2305020337    SHA230502002711814eq  2023-05-02  发货单  网站预订
# 2       DP2305020338    SHA230502002155443cj  2023-05-02  发货单  网站预订
# 3       DP2305020339    SHA2305020018294849c  2023-05-02  发货单  网站预订
# 4       DP2305020340    SHA23050200144820645  2023-05-02  发货单  网站预订
# ...              ...                     ...         ...  ...   ...
# 476584   DP230507284    GZA230507142909576lq  2023-05-07  发货单  网站预订
# 476585   DP230504008    GZA230503175138463ix  2023-05-04  发货单  网站预订
# 476586   DP230504344  GZA230504151842035no_1  2023-05-04  发货单  网站预订
# 476587   DP230507017    GZA2305061731208043d  2023-05-07  发货单  网站预订
# 476588   DP230530091    GZA230530082445689st  2023-05-30  发货单  网站预订
#
# ...

# %%
df1 = df3.copy()
df1
df1.to_csv('C:/Users/LC-/Desktop/1.csv')
